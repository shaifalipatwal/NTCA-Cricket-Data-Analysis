# %% [markdown]
# # **2024 NTCA Legacy T20 - Super Division**
#
# ## Batting Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
batting_df= pd.read_excel("C:\\Users\\SHAIFALI PATWAL\\Downloads\\Internship sheets\\2024 NTCA Legacy T20 - super division.xlsx", sheet_name="batting", header=0)
batting_df.head()
# Out:
#    # ↓               Player  ↓ Group  ↓                 Team  ↓  Mat  ↓  \
# 0    1            Haladhar Das        E   Texas Cricket Academy       7
# 1    2      Jaafar Shahabuddin        C             NDCC Risers       6
# 2    3             Baswant Rao        B             NDCC Wolves       7
# 3    4         Himanshu Sharma        A            MCA Mustangs       5
# 4    5   Nallasivam Neminathan        B           Mighty Eagles       7
#
#    Ins  ↓  No  ↓  Runs  ↓  Balls  ↓ Avg  ↓   Sr  ↓  Hs  ↓  100's  ↓  75's  ↓  \
# 0       7      1      354       196     59  180.61     91         0        2
# 1       6      1      345       204     69  169.12    105         1        0
# 2       7      1      283       207  47.17  136.71     83         0        1
# 3       5      1      254       122   63.5  208.20    103         1        0
# 4       6      2      253       114  63.25  221.93     68         0        0
#
#    50's  ↓  25's  ↓  0  ↓  6's  ↓  4's  ↓
# ...

# %%
batting_df.columns= batting_df.columns.str.replace("↓","")
batting_df.columns=batting_df.columns.str.strip()
batting_df.columns
# Out:
# Index(['#', 'Player', 'Group', 'Team', 'Mat', 'Ins', 'No', 'Runs', 'Balls',
#        'Avg', 'Sr', 'Hs', '100's', '75's', '50's', '25's', '0', '6's', '4's'],
#       dtype='object')

# %%
batting_df.set_index(batting_df.columns[0],inplace=True)
batting_df=batting_df.replace(u'\xa0', u'', regex=True)

# %%
batting_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 874 entries, 1 to 874
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  874 non-null    object
#  1   Group   874 non-null    object
#  2   Team    874 non-null    object
#  3   Mat     874 non-null    int64
#  4   Ins     874 non-null    int64
#  5   No      874 non-null    int64
#  6   Runs    874 non-null    int64
#  7   Balls   874 non-null    int64
#  8   Avg     874 non-null    object
#  9   Sr      874 non-null    float64
#  10  Hs      874 non-null    int64
#  11  100's   874 non-null    int64
#  12  75's    874 non-null    int64
#  13  50's    874 non-null    int64
#  14  25's    874 non-null    int64
#  15  0       874 non-null    int64
#  16  6's     874 non-null    int64
#  17  4's     874 non-null    int64
# dtypes: float64(1), int64(13), object(4)
# memory usage: 129.7+ KB

# %%
batting_df.shape
# Out:
# (874, 18)

# %%
# Changing Avg to float
batting_df["Avg"]=pd.to_numeric(batting_df["Avg"],errors="coerce")
batting_df["Avg"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 874 entries, 1 to 874
# Series name: Avg
# Non-Null Count  Dtype
# --------------  -----
# 659 non-null    float64
# dtypes: float64(1)
# memory usage: 13.7 KB

# %%
batting_df.isna().sum()
# Out:
# Player      0
# Group       0
# Team        0
# Mat         0
# Ins         0
# No          0
# Runs        0
# Balls       0
# Avg       215
# Sr          0
# Hs          0
# 100's       0
# 75's        0
# 50's        0
# 25's        0
# 0           0
# 6's         0
# 4's         0
# dtype: int64

# %%
batting_df['Avg'] = batting_df['Runs'] / (batting_df['Ins'] - batting_df['No'])
batting_df.head()
# Out:
#                   Player Group                   Team  Mat  Ins  No  Runs  \
# #
# 1           Haladhar Das     E  Texas Cricket Academy    7    7   1   354
# 2     Jaafar Shahabuddin     C            NDCC Risers    6    6   1   345
# 3            Baswant Rao     B            NDCC Wolves    7    7   1   283
# 4        Himanshu Sharma     A           MCA Mustangs    5    5   1   254
# 5  Nallasivam Neminathan     B          Mighty Eagles    7    6   2   253
#
#    Balls        Avg      Sr   Hs  100's  75's  50's  25's  0  6's  4's
# #
# 1    196  59.000000  180.61   91      0     2     2     4  0   15   30
# 2    204  69.000000  169.12  105      1     0     4     0  0   17   27
# 3    207  47.166667  136.71   83      0     1     3     3  0    8   24
# 4    122  63.500000  208.20  103      1     0     2     1  0   14   32
# 5    114  63.250000  221.93   68      0     0     3     0  0   20   18

# %%
batting_df["Avg"].isna().sum()
# Out:
# 135

# %%
batting_df["Avg"].fillna(0, inplace=True)
# Out:
# C:\Users\SHAIFALI PATWAL\AppData\Local\Temp\ipykernel_4656\179900426.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   batting_df["Avg"].fillna(0, inplace=True)

# %%
batting_df["Avg"].isna().sum()
# Out:
# 0

# %%
batting_df.head(2)
# Out:
#                Player Group                   Team  Mat  Ins  No  Runs  Balls  \
# #
# 1        Haladhar Das     E  Texas Cricket Academy    7    7   1   354    196
# 2  Jaafar Shahabuddin     C            NDCC Risers    6    6   1   345    204
#
#     Avg      Sr   Hs  100's  75's  50's  25's  0  6's  4's
# #
# 1  59.0  180.61   91      0     2     2     4  0   15   30
# 2  69.0  169.12  105      1     0     4     0  0   17   27

# %%
batting_df.describe()
# Out:
# c:\Users\SHAIFALI PATWAL\anaconda3\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#               Mat         Ins          No        Runs       Balls    Avg  \
# count  874.000000  874.000000  874.000000  874.000000  874.000000  874.0
# mean     2.921053    2.215103    0.463387   34.576659   29.241419    inf
# std      2.019252    1.844331    0.739438   49.782935   35.994814    NaN
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.0
# 25%      1.000000    1.000000    0.000000    2.000000    4.000000    2.0
# 50%      2.000000    2.000000    0.000000   14.500000   15.000000   11.0
# 75%      4.000000    3.000000    1.000000   46.000000   41.000000   27.0
# max      9.000000    9.000000    5.000000  354.000000  207.000000    inf
#
#                Sr          Hs       100's        75's        50's        25's  \
# ...

# %%
# Check for infinity values in the dataframe
np.isinf(batting_df["Avg"]).sum()
# Out:
# 80

# %%
# Replacing infinity valuess with 0
batting_df["Avg"].replace([np.inf, -np.inf], np.nan, inplace=True)
np.isinf(batting_df["Avg"]).sum()
# Out:
# C:\Users\SHAIFALI PATWAL\AppData\Local\Temp\ipykernel_4656\1654418175.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   batting_df["Avg"].replace([np.inf, -np.inf], np.nan, inplace=True)
# 0

# %%
batting_df.describe()
# Out:
#               Mat         Ins          No        Runs       Balls         Avg  \
# count  874.000000  874.000000  874.000000  874.000000  874.000000  794.000000
# mean     2.921053    2.215103    0.463387   34.576659   29.241419   14.738093
# std      2.019252    1.844331    0.739438   49.782935   35.994814   17.635041
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    1.000000    0.000000    2.000000    4.000000    1.000000
# 50%      2.000000    2.000000    0.000000   14.500000   15.000000   10.000000
# 75%      4.000000    3.000000    1.000000   46.000000   41.000000   21.000000
# max      9.000000    9.000000    5.000000  354.000000  207.000000  137.000000
#
#                Sr          Hs       100's        75's        50's        25's  \
# count  874.000000  874.000000  874.000000  874.000000  874.000000  874.000000
# mean    84.619451   19.300915    0.010297    0.025172    0.135011    0.343249
# ...

# %% [markdown]
# ### **DATA VISUALIZATION**

# %%
# Histogram of Runs
plt.figure(figsize=(8,5))
sns.histplot(batting_df["Runs"],bins=10, kde=True, color="green")
plt.title("Histogram of Runs")
plt.xlabel("Runs")
plt.ylabel("Frequency")
# Out:
# c:\Users\SHAIFALI PATWAL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
# Histogram of Avg Scores
plt.figure(figsize=(8,5))
sns.histplot(batting_df["Avg"],bins=10, kde=True, color="green")
plt.title("Histogram of Avg")
plt.xlabel("Avg")
plt.ylabel("Frequency")
# Out:
# c:\Users\SHAIFALI PATWAL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### **Top five Batsmen according to batting stats**
#
# Created a dataframe top_batsmen of players who played min 5 matches and min 5 innings, sorted by the runs scored

# %%
batting_df.columns
# Out:
# Index(['Player', 'Group', 'Team', 'Mat', 'Ins', 'No', 'Runs', 'Balls', 'Avg',
#        'Sr', 'Hs', '100's', '75's', '50's', '25's', '0', '6's', '4's'],
#       dtype='object')

# %%
# Maxinmum matches played in the tournament
batting_df['Mat'].max()
# Out:
# 9

# %%
top_batsman= batting_df[(batting_df["Mat"]>=6) & (batting_df["Ins"]>=5)][["Player","Team","Mat","Ins","Runs","Balls","Avg","Sr"]].sort_values("Runs", ascending=False)
top_batsman.head()
# Out:
#                   Player                   Team  Mat  Ins  Runs  Balls  \
# #
# 1           Haladhar Das  Texas Cricket Academy    7    7   354    196
# 2     Jaafar Shahabuddin            NDCC Risers    6    6   345    204
# 3            Baswant Rao            NDCC Wolves    7    7   283    207
# 5  Nallasivam Neminathan          Mighty Eagles    7    6   253    114
# 6       Madhivanan Durai          Gpcc Shaheens    8    8   248    178
#
#          Avg      Sr
# #
# 1  59.000000  180.61
# 2  69.000000  169.12
# 3  47.166667  136.71
# 5  63.250000  221.93
# 6  41.333333  139.33

# %% [markdown]
# ### **Top 2 Batsmen in each teams**

# %%
top_Bat_by_teams= batting_df[(batting_df["Mat"]>=6) & (batting_df["Ins"]>=5)][["Player","Team","Ins","Mat","Runs","Balls","Avg","Sr"]].sort_values(['Team', 'Runs'], ascending=[True, False])
top_Bat_by_teams.groupby('Team').head(2)
# Out:
#                        Player                       Team  Ins  Mat  Runs  \
# #
# 172            Manoj Katreddy                     DCCC 3    6    6    60
# 190             Kausik Valeti                     DCCC 3    6    6    55
# 35               Rajeev Menon              Elite Jaguars    6    6   160
# 32               Haris Rahman            Fortworth Lions    6    6   162
# 110              Abdul Raheem            Fortworth Lions    6    6    83
# 63                 Sachin Sah              Frisco Tigers    5    6   112
# 80                 Taha Badar               GPCC Sultans    5    6   103
# 6            Madhivanan Durai              Gpcc Shaheens    8    8   248
# 50              Faisal Akhtar              Gpcc Shaheens    7    8   130
# 242          Mohsin Banderkar             Hawks Badshahs    5    6    42
# 7               Saif Farooqui           ICC Texan Tigers    6    6   248
# 46              Amer Mohammed           ICC Texan Tigers    5    6   132
# ...

# %% [markdown]
# #### **Players with 100's and 50's**

# %%
batting_df[(batting_df["100\'s"]>=1) & (batting_df["50\'s"]>=1)][["Player","100\'s","75\'s",'50\'s',"25\'s"]]
# Out:
#                    Player  100's  75's  50's  25's
# #
# 2      Jaafar Shahabuddin      1     0     4     0
# 4         Himanshu Sharma      1     0     2     1
# 8            Rishi Ramesh      1     0     1     1
# 11      Tarun Bhoomireddy      1     0     1     1
# 15  Sanil (Sunny) Meshram      1     0     1     1
# 26           Arjun Mahesh      1     0     1     0

# %% [markdown]
# ### **Feature Engineering**

# %%
# Batting Consistency Metrics:This metric can help quantify how consistent a player is across different matches.
batting_df['Consistency_Score'] = batting_df['25\'s']+ batting_df['50\'s'] + batting_df['75\'s'] + batting_df['100\'s'] - batting_df['0']

# %%
# Boundary Percentage: This metric provides insights into the player's playing style.
batting_df["Boundary%"]= (batting_df['4\'s'] + batting_df['6\'s']) / batting_df['Runs'] * 100

# %%
# Runs per Match: This metric can indicate a player's performance consistency over all matches played.
batting_df["Runs_per_match"]= batting_df["Runs"] / batting_df["Mat"]

# %%
# Runs per Innings: This feature is useful for comparing players based on how many runs they score on average when they get a chance to bat.
batting_df['Runs_per_Innings'] = batting_df['Runs'] / batting_df['Ins']

# %%
# No. of Not-outs to Matches Ratio: It indicates the player's ability to finish the game.
batting_df['Not_out_Ratio'] = batting_df['No'] / batting_df['Mat']

# %%
batting_df.head(2)
# Out:
#                Player Group                   Team  Mat  Ins  No  Runs  Balls  \
# #
# 1        Haladhar Das     E  Texas Cricket Academy    7    7   1   354    196
# 2  Jaafar Shahabuddin     C            NDCC Risers    6    6   1   345    204
#
#     Avg      Sr  ...  50's  25's  0  6's  4's  Consistency_Score  Boundary%  \
# #                ...
# 1  59.0  180.61  ...     2     4  0   15   30                  8  12.711864
# 2  69.0  169.12  ...     4     0  0   17   27                  5  12.753623
#
#    Runs_per_match  Runs_per_Innings  Not_out_Ratio
# #
# 1       50.571429         50.571429       0.142857
# 2       57.500000         57.500000       0.166667
#
# [2 rows x 23 columns]

# %%
batting_df.columns
# Out:
# Index(['Player', 'Group', 'Team', 'Mat', 'Ins', 'No', 'Runs', 'Balls', 'Avg',
#        'Sr', 'Hs', '100's', '75's', '50's', '25's', '0', '6's', '4's',
#        'Consistency_Score', 'Boundary%', 'Runs_per_match', 'Runs_per_Innings',
#        'Not_out_Ratio'],
#       dtype='object')

# %% [markdown]
# ### **Machine Learning Models**
